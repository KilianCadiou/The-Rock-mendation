# %%
chemin_bd = 0

# %%
df = pd.read.csv(chemin, compression = 'gzip', sep = '\t', nrows = )

# %%
import pandas as pd

# %%
# Name Basics

link = "./BD/name.basics.tsv.gz"
df_name_basics = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_name_basics.info()
df_name_basics.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13956187 entries, 0 to 13956186
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          object
#  3   deathYear          object
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: object(6)
# memory usage: 638.9+ MB

# %%
# Title Akas

link = "./BD/title.akas.tsv.gz"
df_title_akas = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_title_akas.info()
df_title_akas.sample(5)
# Out:
#              titleId  ordering  \
# 43762082   tt6704356         8
# 3389474    tt0826595         1
# 21359536  tt17515438         8
# 33987635  tt30611538         1
# 22503695   tt1889163         3
#
#                                                       title region language  \
# 43762082                                      Episodio #1.7     ES       es
# 3389474   El pato Baratucci, en... El regreso del morsa:...     \N       \N
# 21359536                                   Episodio #1.9023     ES       es
# 33987635               2004-05: Getafe vs Barcelona (11/27)     \N       \N
# 22503695                   26 मार्च 1999 को प्रसारित एपिसोड     IN       hi
#
#              types attributes  isOriginalTitle
# 43762082        \N         \N                0
# 3389474   original         \N                1
# 21359536        \N         \N                0
# 33987635  original         \N                1
# 22503695        \N         \N                0

# %%
# Title crew

link = "./BD/title.crew.tsv.gz"
df_title_crew = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_title_crew.info()
df_title_crew.sample(5)
# Out:
#              tconst            directors  \
# 6133205  tt27316910           nm12424117
# 320991    tt0330921            nm0470749
# 4166211  tt16406894            nm0041715
# 8684795   tt5530994  nm2237374,nm1235963
# 8533879   tt5157450            nm3686904
#
#                                                    writers
# 6133205                                         nm12424117
# 320991                                           nm0470749
# 4166211  nm0479525,nm0996410,nm0909625,nm0934807,nm1180...
# 8684795                                                 \N
# 8533879                                nm3686904,nm3590332

# %%
# Title basics

link = "./BD/title.basics.tsv.gz"
df_title_basics = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_title_basics.info()
df_title_basics.sample(5)
# Out:
# /var/folders/2b/18xblx_n4lv24wz932vjckrm0000gp/T/ipykernel_9528/2739964111.py:4: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_title_basics = pd.read_csv(link, compression = 'gzip', sep = '\t')
#              tconst  titleType       primaryTitle      originalTitle isAdult  \
# 546757    tt0568044  tvEpisode  Middle of Nowhere  Middle of Nowhere       0
# 2079032  tt12004328  tvEpisode   Hortence Refuses   Hortence Refuses       0
# 7945554  tt32907832  tvEpisode     Episode #1.303     Episode #1.303       0
# 9001972   tt4954446  tvEpisode      Episode #8.78      Episode #8.78       0
# 7806778  tt32481632  tvEpisode   Babies on Board!   Babies on Board!       0
#
#         startYear endYear runtimeMinutes                 genres
# 546757       1999      \N             45          Drama,Romance
# 2079032      2020      \N             \N              Animation
# 7945554      1997      \N             35                   News
# ...

# %%
# Title Episode

link = "./BD/title.episode.tsv.gz"
df_title_episode = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_title_episode.info()
df_title_episode.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8637946 entries, 0 to 8637945
# Data columns (total 4 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   tconst         object
#  1   parentTconst   object
#  2   seasonNumber   object
#  3   episodeNumber  object
# dtypes: object(4)
# memory usage: 263.6+ MB

# %%
# Title principals

link = "./BD/title.principals.tsv.gz"
df_title_principals = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_title_principals.info()
df_title_principals.sample(5)
# Out:
#               tconst  ordering     nconst         category job  \
# 29510312  tt14333094         3  nm1708661             self  \N
# 86685024   tt9331706         8  nm0180569            actor  \N
# 72733542   tt5678100         1  nm1731421             self  \N
# 64706931  tt34140682         6  nm9494664            actor  \N
# 1338193    tt0094822        15  nm0273795  cinematographer  \N
#
#                                characters
# 29510312  ["Self - Sports Correspondent"]
# 86685024  ["Don Miguel Laureano Múzquiz"]
# 72733542                         ["Self"]
# 64706931               ["Rajveer Luthra"]
# 1338193                                \N

# %%
# Title ratings

link = "./BD/title.ratings.tsv.gz"
df_title_ratings = pd.read_csv(link, compression = 'gzip', sep = '\t')
df_title_ratings.info()
df_title_ratings.sample(5)
# Out:
#            tconst  averageRating  numVotes
# 883794  tt2009292            7.0         6
# 920287  tt2148198            7.1        12
# 748045  tt1520599            8.5        24
# 220120  tt0380979            5.8        25
# 331655  tt0629526            8.0       333

# %%
# TMDB Full

link = "./BD/tmdb_full.csv"
df_tmdb_full = pd.read_csv(link)
df_tmdb_full.info()
df_tmdb_full.sample(5)
# Out:
# /var/folders/2b/18xblx_n4lv24wz932vjckrm0000gp/T/ipykernel_9528/1852878264.py:4: DtypeWarning: Columns (24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_tmdb_full = pd.read_csv(link)
#         adult                     backdrop_path  budget  \
# 155263  False                               NaN       0
# 78463   False  /u3cfNTe5mZjjqkCWiQiiCKS47MO.jpg       0
# 184211  False  /8sFZA0vXoJTFxD0CUKO14LDlo7A.jpg       0
# 119815  False                               NaN       0
# 15939   False   /PFJ2wNS3m5A85CFNPszc3bbDsc.jpg       0
#
#                                  genres homepage       id     imdb_id  \
# 155263                       ['Action']      NaN  1102607  tt22794158
# 78463                         ['Drama']      NaN   595490   tt9665400
# 184211                  ['Documentary']      NaN    50504   tt0457293
# 119815  ['Action', 'Drama', 'Thriller']      NaN   433706   tt0275364
# ...
